# %%
import pandas as pd
data=pd.read_csv("ontology_data.csv")
data.head(10)
# Out:
#    ID                                         Input_Text  \
# 0   1  The Falcon 9 is a reusable rocket designed by ...
# 1   2  The human heart is a muscular organ that pumps...
# 2   3  Microsoft Corporation officially acquired Link...
# 3   4  Photosynthesis is a process used by plants to ...
# 4   5  A microservices architecture divides an applic...
# 5   6  The Great Pyramid of Giza was built for the Ph...
# 6   7  Type 1 diabetes occurs when the pancreas produ...
# 7   8  Albert Einstein developed the theory of genera...
# 8   9  The Amazon Rainforest produces a significant p...
# 9  10  Blockchain technology serves as the foundation...
#
#                                       Entity_Classes  \
# 0  Launch Vehicle | Aerospace Manufacturer | Rock...
# 1  Organ | Bodily Fluid | Anatomical System | Hea...
# 2  Technology Company | Social Networking Service...
# 3  Metabolic Pathway | Organism | Energy Form (Li...
# 4  Software Architectural Style | Software Applic...
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Input_Text', 'Entity_Classes', 'Relationships', 'Triplets',
#        'Source_Sentences', 'Predicted_Entity_Classes',
#        'Predicted_Relationships', 'Predicted_Triplets',
#        'Predicted_Source_Sentences', 'Entity_Classes_Accuracy',
#        'Relationships_Accuracy', 'Triplets_Accuracy', 'Position_Accuracy',
#        'Matched_Entity_Pairs', 'Matched_Relationship_Pairs',
#        'Matched_Triplet_Pairs'],
#       dtype='str')

# %%
data["Entity_Classes_Accuracy"]
# Out:
# 0    0.333333
# 1    0.428571
# 2    0.400000
# 3    0.100000
# 4    0.333333
# 5    0.500000
# 6    0.285714
# 7    0.166667
# 8    0.428571
# 9    0.166667
# Name: Entity_Classes_Accuracy, dtype: float64

# %%
data["Relationships_Accuracy"]
# Out:
# 0    0.75
# 1    0.75
# 2    0.25
# 3    0.60
# 4    0.50
# 5    1.00
# 6    0.40
# 7    0.50
# 8    0.25
# 9    0.75
# Name: Relationships_Accuracy, dtype: float64

# %%
data["Triplets_Accuracy"][0]
# Out:
# np.float64(0.6)

# %%
data["Position_Accuracy"]
# Out:
# 0    1.000000
# 1    1.000000
# 2    0.000000
# 3         NaN
# 4    0.666667
# 5    0.666667
# 6         NaN
# 7         NaN
# 8    0.000000
# 9    1.000000
# Name: Position_Accuracy, dtype: float64

# %%
data["Entity_Classes_Accuracy"].mean()
# Out:
# np.float64(0.3142857142857142)

# %%
data["Relationships_Accuracy"].mean()
# Out:
# np.float64(0.575)

# %%
data["Triplets_Accuracy"].mean()
# Out:
# np.float64(0.375)

# %%
data["Position_Accuracy"]
# Out:
# 0    1.000000
# 1    1.000000
# 2    0.000000
# 3         NaN
# 4    0.666667
# 5    0.666667
# 6         NaN
# 7         NaN
# 8    0.000000
# 9    1.000000
# Name: Position_Accuracy, dtype: float64

# %%
data['Position_Accuracy'].mean()
# Out:
# np.float64(0.619047619047619)

# %%
data["Triplets"][0]
# Out:
# '(Launch Vehicle, designed by, Aerospace Manufacturer) | (Launch Vehicle, utilizes, Rocket Engine) | (Rocket Engine, burns, Oxidizer) | (Rocket Engine, burns, Propellant) | (Aerospace Manufacturer, landed, Rocket Stage)'

# %%
data["Predicted_Triplets"][0]
# Out:
# '(Rocket, isA, Vehicle) | (Rocket, designed_by, Corporation) | (Rocket, utilizes, Engine) | (Engine, burns, Fuel) | (Fuel, isA, LiquidFuel) | (Organization, performsAction, Landing)'

# %%
data["Matched_Triplet_Pairs"][7]
# Out:
# nan

# %%
data["Input_Text"][7]
# Out:
# 'Albert Einstein developed the theory of general relativity in 1915. The theory describes the gravitational attraction between masses as a result of the warping of spacetime. Large masses like the Sun curve the fabric of the universe. This curvature dictates the motion of planets in their orbits.'

# %%
data["Entity_Classes"][7]
# Out:
# 'Physicist | Scientific Theory | Physical Object | Physical Concept (Spacetime) | Star | Celestial Body'

# %%
data["Predicted_Entity_Classes"][7]
# Out:
# 'Theory | ScientificConcept | PhysicalPhenomenon | Mass | Spacetime | GravitationalAttraction | Motion | Orbit'

# %%
data["Triplets"][7]
# Out:
# '(Physicist, developed, Scientific Theory) | (Scientific Theory, describes, Gravitational Attraction) | (Star, curve, Physical Concept (Spacetime)) | (Curvature, dictates, Motion of Celestial Body)'

# %%
data["Predicted_Triplets"][7]
# Out:
# '(Theory, describes, ScientificConcept) | (Theory, relates to, PhysicalPhenomenon) | (ScientificConcept, is a, PhysicalPhenomenon) | (Mass, experiences, GravitationalAttraction) | (Mass, causes, Spacetime) | (Spacetime, is warped by, Mass) | (Spacetime, dictates, Motion) | (Motion, is influenced by, Orbit) | (Orbit, is influenced by, Spacetime)'

# %%
data["Entity_Classes_Accuracy"][7]
# Out:
# np.float64(0.1666666666666666)

# %%
data["Matched_Entity_Pairs"][7]
# Out:
# '(GT: Scientific Theory -> PR: Theory)'
